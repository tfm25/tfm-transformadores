# %% [markdown]
# # Leer data transformadores

# %%
import pandas as pd

# Lee el archivo CSV
df_transformadores = pd.read_csv('df_rellenado_con_nans.csv')

# Muestra las primeras filas del DataFrame
df_transformadores.head()
# Out:
#           Fecha y hora  \
# 0  2021-01-01 00:30:00
# 1  2021-01-01 00:45:00
# 2  2021-01-01 01:00:00
# 3  2021-01-01 01:15:00
# 4  2021-01-01 01:30:00
#
#    SE_Valparaiso.Trf_Valparaiso_T1 Potencia activa media (kW)  \
# 0                                        6657.061100
# 1                                        6600.084782
# 2                                        6579.427719
# 3                                        6523.938179
# 4                                        6389.933586
#
#    SE_Valparaiso.Trf_Valparaiso_T1 Potencia reactiva media (kVAr)  \
# 0                                         392.181486
# 1                                         370.762348
# 2                                         385.641813
# 3                                         389.757663
# 4                                         364.311010
#
#    SE_Placeres.Trf_Placeres_T1 Potencia activa media (kW)  \
# 0                                        9087.688446
# ...

# %%
df_transformadores['Fecha y hora'] = pd.to_datetime(df_transformadores['Fecha y hora'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import os

transformador_columnas_p = [
    "SE_Valparaiso.Trf_Valparaiso_T1 Potencia activa media (kW)",
    "SE_Placeres.Trf_Placeres_T1 Potencia activa media (kW)",
    "SE_Placeres.Trf_Placeres_T2 Potencia activa media (kW)",
    "SE_Placilla.Trf_Placilla_T2 Potencia activa media (kW)",
    "SE_Bosquemar.Trf_Bosquemar_T1 Potencia activa media (kW)",
    "SE_Bosquemar.Trf_Bosquemar_T2 Real Power Mean (kW)",
    "SE_Playa_Ancha.Trf_Playa_Ancha_T1 Potencia activa media (kW)",
    "SE_Playa_Ancha.Trf_Playa_Ancha_T2 Potencia activa media (kW)",
    "SE_Calera.Trf_Calera_T2 Potencia activa media (kW)"
]

# %%
# Unir ambas listas de columnas
columnas_a_convertir = transformador_columnas_p 

# Aplicar la conversión: dividir por 1000
df_transformadores[columnas_a_convertir] = df_transformadores[columnas_a_convertir] / 1000

# %%
# Asegúrate de que la columna 'Fecha y hora' sea de tipo datetime
df_transformadores['Fecha y hora'] = pd.to_datetime(df_transformadores['Fecha y hora'])

# Mostrar la fecha mínima y máxima
fecha_min = df_transformadores['Fecha y hora'].min()
fecha_max = df_transformadores['Fecha y hora'].max()

print("Fecha mínima:", fecha_min)
print("Fecha máxima:", fecha_max)
# Out:
# Fecha mínima: 2021-01-01 00:30:00
# Fecha máxima: 2025-04-21 00:00:00

# %%
# Definir las fechas de inicio y fin
fecha_inicio = pd.to_datetime('2022-09-01 00:00:00')
fecha_fin = pd.to_datetime('2025-04-08 00:00:00')

# Filtrar el DataFrame para que solo contenga registros entre fecha_inicio y fecha_fin
df_transformadores = df_transformadores[(df_transformadores['Fecha y hora'] >= fecha_inicio) & (df_transformadores['Fecha y hora'] <= fecha_fin)]

# %%
df_transformadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91201 entries, 58366 to 149566
# Data columns (total 31 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Fecha y hora                                                      91201 non-null  datetime64[ns]
#  1   SE_Valparaiso.Trf_Valparaiso_T1 Potencia activa media (kW)        91201 non-null  float64
#  2   SE_Valparaiso.Trf_Valparaiso_T1 Potencia reactiva media (kVAr)    91201 non-null  float64
#  3   SE_Placeres.Trf_Placeres_T1 Potencia activa media (kW)            91201 non-null  float64
#  4   SE_Placeres.Trf_Placeres_T1 Potencia reactiva media (kVAr)        91201 non-null  float64
#  5   SE_Placeres.Trf_Placeres_T2 Potencia activa media (kW)            91201 non-null  float64
#  6   SE_Placeres.Trf_Placeres_T2 Potencia reactiva media (kVAr)        91201 non-null  float64
# ...

# %% [markdown]
# # Instalación de librerias

# %%
# !pip install prophet

# %%
from prophet import Prophet
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Ejecución para los diferentes transformadores

# %% [markdown]
# ### Sin GAP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os

# Crear carpeta de salida
output_dir = "resultados_prophet"
os.makedirs(output_dir, exist_ok=True)

# Función para calcular MAPE
def calcular_mape(y_true, y_pred, min_denominador=1.0):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true >= min_denominador
    if np.any(mask):
        return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
    else:
        return np.nan

# Función base Prophet con dos salidas
def ejecutar_modelo_prophet(df, columna, fecha_inicio_test, mostrar_grafico=False, ruta_guardado=None):
    df_prophet = df[['Fecha y hora', columna]].dropna().rename(columns={
        'Fecha y hora': 'ds', columna: 'y'
    })
    df_prophet['ds'] = pd.to_datetime(df_prophet['ds'])

    fecha_inicio_test = pd.to_datetime(fecha_inicio_test)
    fecha_fin_test = fecha_inicio_test + pd.Timedelta(days=7)

    fecha_fin_train_eval = fecha_inicio_test - pd.Timedelta(minutes=15)
    fecha_inicio_train = fecha_fin_train_eval - pd.Timedelta(weeks=52)
    fecha_inicio_train_eval = fecha_fin_train_eval - pd.Timedelta(weeks=1) + pd.Timedelta(minutes=15)

    df_test = df_prophet[(df_prophet['ds'] >= fecha_inicio_test) & (df_prophet['ds'] < fecha_fin_test)].copy()
    df_train_eval = df_prophet[(df_prophet['ds'] >= fecha_inicio_train_eval) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()
    df_train = df_prophet[(df_prophet['ds'] >= fecha_inicio_train) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()

    m = Prophet()
    m.fit(df_train)

    future = pd.concat([df_train_eval[['ds']], df_test[['ds']]]).drop_duplicates().sort_values('ds')
    forecast = m.predict(future)

    forecast_train_eval = forecast[forecast['ds'].isin(df_train_eval['ds'])]
    forecast_test = forecast[forecast['ds'].isin(df_test['ds'])]

    df_train_eval = df_train_eval.set_index('ds').join(forecast_train_eval.set_index('ds')[['yhat']], how='inner')
    df_test_eval = df_test.set_index('ds').join(forecast_test.set_index('ds')[['yhat']], how='inner')

    mae_train = mean_absolute_error(df_train_eval['y'], df_train_eval['yhat'])
    rmse_train = np.sqrt(mean_squared_error(df_train_eval['y'], df_train_eval['yhat']))
    mape_train = calcular_mape(df_train_eval['y'], df_train_eval['yhat'])

    mae_test = mean_absolute_error(df_test_eval['y'], df_test_eval['yhat'])
    rmse_test = np.sqrt(mean_squared_error(df_test_eval['y'], df_test_eval['yhat']))
    mape_test = calcular_mape(df_test_eval['y'], df_test_eval['yhat'])

    if mostrar_grafico or ruta_guardado:
        plt.figure(figsize=(12, 4))
        plt.plot(df_test_eval.index, df_test_eval['y'], label='Real')
        plt.plot(df_test_eval.index, df_test_eval['yhat'], label='Predicción')
        plt.title(f'{columna} [{fecha_inicio_test.date()}]')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()

        if ruta_guardado:
            plt.savefig(ruta_guardado)
        if mostrar_grafico:
            plt.show()
        else:
            plt.close()

    # Armar resultados de métricas
    resultados_metricas = {
        'transformador': columna,
        'fecha_inicio_test': fecha_inicio_test.date(),
        'MAE_train': mae_train, 'RMSE_train': rmse_train, 'MAPE_train': mape_train,
        'MAE_test': mae_test, 'RMSE_test': rmse_test, 'MAPE_test': mape_test
    }

    # Agregar identificador al df de predicción
    df_test_eval = df_test_eval.reset_index()
    df_test_eval['transformador'] = columna
    df_test_eval = df_test_eval.rename(columns={'y': 'real', 'yhat': 'predicho'})

    return resultados_metricas, df_test_eval

# %%
from datetime import timedelta

# Define estaciones según hemisferio sur
estaciones_meses = {
    'primavera': [9, 10, 11],
    'verano': [12, 1, 2],
    'otoño': [3, 4, 5],
    'invierno': [6, 7, 8]
}

# Fechas límites
inicio_data = pd.to_datetime("2022-09-01")
fin_data = pd.to_datetime("2025-04-02")
duracion_entrenamiento = timedelta(weeks=52)
gap = timedelta(weeks=3)
duracion_test = timedelta(days=7)

# Extraer fechas candidatas desde la columna 'Fecha y hora'
fechas_disponibles = pd.Series(pd.to_datetime(df_transformadores["Fecha y hora"].dropna().unique()))
fechas_disponibles = fechas_disponibles.sort_values()


def seleccionar_fechas_test(estacion, meses_objetivo, cantidad=4, min_dias_entre_fechas=21):
    candidatos = []
    fechas_filtradas = fechas_disponibles[
        (fechas_disponibles.dt.weekday == 0) &  # lunes
        (fechas_disponibles.dt.hour == 0) &     # a las 00:00
        (fechas_disponibles.dt.minute == 0) &   # y minuto 00
        (fechas_disponibles.dt.month.isin(meses_objetivo))
    ].sort_values(ascending=False)  # orden descendente

    for fecha in fechas_filtradas:
        # Validar que haya suficiente data de entrenamiento
        inicio_entrenamiento = fecha - gap - duracion_entrenamiento
        if inicio_entrenamiento < inicio_data or (fecha + duracion_test) > fin_data:
            continue
        # Evitar semanas muy cercanas entre sí
        if any(abs((fecha - f).days) < min_dias_entre_fechas for f in candidatos):
            continue
        candidatos.append(fecha)
        if len(candidatos) == cantidad:
            break
    return candidatos


# Armar el diccionario completo
fechas_test_por_estacion = {
    estacion: seleccionar_fechas_test(estacion, meses)
    for estacion, meses in estaciones_meses.items()
}

# %%
# Crear carpeta para guardar gráficos si no existe
carpeta_graficos = "graficos_resultados_1_año"
os.makedirs(carpeta_graficos, exist_ok=True)

# Listas para acumular resultados
resultados = []
predicciones_todas = []

# Bucle principal
for transformador in transformador_columnas_p:
    for estacion, fechas in fechas_test_por_estacion.items():
        for fecha in fechas:
            try:
                # Formatear fecha para nombre de archivo
                fecha_str = fecha.strftime("%Y-%m-%d_%H-%M")

                # Limpiar nombre del transformador para archivo
                nombre_archivo = (
                    transformador.replace(" ", "_")
                    .replace(".", "_")
                    .replace("(", "")
                    .replace(")", "")
                    .replace("/", "_")
                )
                ruta_grafico = os.path.join(carpeta_graficos, f"{nombre_archivo}_{fecha_str}.png")

                # Ejecutar modelo (ahora retorna dos cosas)
                resultado, predicciones_test = ejecutar_modelo_prophet(
                    df_transformadores, 
                    columna=transformador, 
                    fecha_inicio_test=fecha, 
                    mostrar_grafico=False,
                    ruta_guardado=ruta_grafico
                )

                # Agregar información contextual a ambos outputs
                resultado["transformador"] = transformador
                resultado["fecha_test"] = fecha
                resultado["estacion"] = estacion
                resultados.append(resultado)

                predicciones_test["fecha_test"] = fecha
                predicciones_test["estacion"] = estacion
                predicciones_todas.append(predicciones_test)

            except Exception as e:
                print(f"Error en {transformador}, {fecha}: {e}")

# Convertir a DataFrame los resultados
df_resultados = pd.DataFrame(resultados)
df_predicciones = pd.concat(predicciones_todas, ignore_index=True)

# Mostrar (o guardar si lo deseas)
print(df_resultados.head())
print(df_predicciones.head())
# Out:
# 20:34:37 - cmdstanpy - INFO - Chain [1] start processing
# 20:34:53 - cmdstanpy - INFO - Chain [1] done processing
# 20:34:54 - cmdstanpy - INFO - Chain [1] start processing
# 20:35:09 - cmdstanpy - INFO - Chain [1] done processing
# 20:35:10 - cmdstanpy - INFO - Chain [1] start processing
# 20:35:25 - cmdstanpy - INFO - Chain [1] done processing
# 20:35:26 - cmdstanpy - INFO - Chain [1] start processing
# 20:35:45 - cmdstanpy - INFO - Chain [1] done processing
# 20:35:45 - cmdstanpy - INFO - Chain [1] start processing
# 20:36:00 - cmdstanpy - INFO - Chain [1] done processing
# 20:36:01 - cmdstanpy - INFO - Chain [1] start processing
# 20:36:16 - cmdstanpy - INFO - Chain [1] done processing
# 20:36:17 - cmdstanpy - INFO - Chain [1] start processing
# 20:36:33 - cmdstanpy - INFO - Chain [1] done processing
# 20:36:34 - cmdstanpy - INFO - Chain [1] start processing
# 20:36:49 - cmdstanpy - INFO - Chain [1] done processing
# 20:36:50 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
with pd.ExcelWriter("resultados_prophet_P_no_invierte.xlsx", engine="openpyxl") as writer:
    df_resultados.to_excel(writer, sheet_name="Metricas", index=False)
    df_predicciones.to_excel(writer, sheet_name="Predicciones", index=False)

# %% [markdown]
# ### Prueba de diferentes Gaps

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
from datetime import timedelta
import os

# CONFIGURACIÓN INICIAL
output_dir = "resultados_prophet"
carpeta_graficos = "graficos_resultados"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(carpeta_graficos, exist_ok=True)

#  MAPE
def calcular_mape(y_true, y_pred, min_denominador=1.0):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true >= min_denominador
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100 if np.any(mask) else np.nan

# MODELO PROPHET 
def ejecutar_modelo_prophet(df, columna, fecha_inicio_test, gap_weeks, mostrar_grafico=False, ruta_guardado=None):
    df_prophet = df[['Fecha y hora', columna]].dropna().rename(columns={'Fecha y hora': 'ds', columna: 'y'})
    df_prophet['ds'] = pd.to_datetime(df_prophet['ds'])

    fecha_inicio_test = pd.to_datetime(fecha_inicio_test)
    fecha_fin_test = fecha_inicio_test + timedelta(days=7)
    fecha_fin_train_eval = fecha_inicio_test - timedelta(weeks=gap_weeks)
    fecha_inicio_train = fecha_fin_train_eval - timedelta(weeks=52)
    fecha_inicio_train_eval = fecha_fin_train_eval - timedelta(weeks=1)

    df_test = df_prophet[(df_prophet['ds'] >= fecha_inicio_test) & (df_prophet['ds'] < fecha_fin_test)].copy()
    df_train_eval = df_prophet[(df_prophet['ds'] >= fecha_inicio_train_eval) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()
    df_train = df_prophet[(df_prophet['ds'] >= fecha_inicio_train) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()

    m = Prophet()
    m.fit(df_train)

    future = pd.concat([df_train_eval[['ds']], df_test[['ds']]]).drop_duplicates().sort_values('ds')
    forecast = m.predict(future)

    forecast_train_eval = forecast[forecast['ds'].isin(df_train_eval['ds'])]
    forecast_test = forecast[forecast['ds'].isin(df_test['ds'])]

    df_train_eval = df_train_eval.set_index('ds').join(forecast_train_eval.set_index('ds')[['yhat']], how='inner')
    df_test_eval = df_test.set_index('ds').join(forecast_test.set_index('ds')[['yhat']], how='inner')

    mae_train = mean_absolute_error(df_train_eval['y'], df_train_eval['yhat'])
    rmse_train = np.sqrt(mean_squared_error(df_train_eval['y'], df_train_eval['yhat']))
    mape_train = calcular_mape(df_train_eval['y'], df_train_eval['yhat'])

    mae_test = mean_absolute_error(df_test_eval['y'], df_test_eval['yhat'])
    rmse_test = np.sqrt(mean_squared_error(df_test_eval['y'], df_test_eval['yhat']))
    mape_test = calcular_mape(df_test_eval['y'], df_test_eval['yhat'])

    if mostrar_grafico or ruta_guardado:
        plt.figure(figsize=(12, 4))
        plt.plot(df_test_eval.index, df_test_eval['y'], label='Real')
        plt.plot(df_test_eval.index, df_test_eval['yhat'], label='Predicción')
        plt.title(f'{columna} [{fecha_inicio_test.date()}]')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        if ruta_guardado:
            plt.savefig(ruta_guardado)
        if mostrar_grafico:
            plt.show()
        else:
            plt.close()

    resultados_metricas = {
        'transformador': columna,
        'fecha_inicio_test': fecha_inicio_test.date(),
        'gap_semanas': gap_weeks,
        'MAE_train': mae_train, 'RMSE_train': rmse_train, 'MAPE_train': mape_train,
        'MAE_test': mae_test, 'RMSE_test': rmse_test, 'MAPE_test': mape_test
    }

    df_test_eval = df_test_eval.reset_index().rename(columns={'y': 'real', 'yhat': 'predicho'})
    df_test_eval['transformador'] = columna

    return resultados_metricas, df_test_eval

# FECHAS CANDIDATAS
inicio_data = pd.to_datetime("2022-09-01")
fin_data = pd.to_datetime("2025-04-02")
duracion_entrenamiento = timedelta(weeks=52)
duracion_test = timedelta(days=7)

estaciones_meses = {
    'primavera': [9, 10, 11],
    'verano': [12, 1, 2],
    'otoño': [3, 4, 5],
    'invierno': [6, 7, 8]
}

fechas_disponibles = pd.Series(pd.to_datetime(df_transformadores["Fecha y hora"].dropna().unique())).sort_values()

def seleccionar_fechas_test(meses_objetivo, gap_weeks, cantidad=2, min_dias_entre_fechas=21):
    candidatos = []
    fechas_filtradas = fechas_disponibles[
        (fechas_disponibles.dt.weekday == 0) &
        (fechas_disponibles.dt.hour == 0) &
        (fechas_disponibles.dt.minute == 0) &
        (fechas_disponibles.dt.month.isin(meses_objetivo))
    ].sort_values(ascending=False)

    for fecha in fechas_filtradas:
        inicio_entrenamiento = fecha - timedelta(weeks=gap_weeks) - duracion_entrenamiento
        if inicio_entrenamiento < inicio_data or (fecha + duracion_test) > fin_data:
            continue
        if any(abs((fecha - f).days) < min_dias_entre_fechas for f in candidatos):
            continue
        candidatos.append(fecha)
        if len(candidatos) == cantidad:
            break
    return candidatos

# ITERAR POR GAPS 
resultados_por_gap = {}
predicciones_por_gap = {}

for gap_weeks in [3, 6, 9, 12]:
    resultados = []
    predicciones_todas = []

    for transformador in transformador_columnas_p:
        for estacion, meses in estaciones_meses.items():
            fechas = seleccionar_fechas_test(meses, gap_weeks)
            for fecha in fechas:
                try:
                    nombre_archivo = (
                        transformador.replace(" ", "_")
                        .replace(".", "_").replace("(", "").replace(")", "").replace("/", "_")
                    )
                    fecha_str = fecha.strftime("%Y-%m-%d_%H-%M")
                    ruta_grafico = os.path.join(carpeta_graficos, f"{nombre_archivo}_{fecha_str}_gap{gap_weeks}.png")

                    resultado, predicciones_test = ejecutar_modelo_prophet(
                        df_transformadores,
                        columna=transformador,
                        fecha_inicio_test=fecha,
                        gap_weeks=gap_weeks,
                        mostrar_grafico=False,
                        ruta_guardado=ruta_grafico
                    )

                    resultado["fecha_test"] = fecha
                    resultado["estacion"] = estacion
                    resultados.append(resultado)

                    predicciones_test["fecha_test"] = fecha
                    predicciones_test["estacion"] = estacion
                    predicciones_test["gap_semanas"] = gap_weeks
                    predicciones_todas.append(predicciones_test)

                except Exception as e:
                    print(f"Error en {transformador}, {fecha}, gap={gap_weeks}: {e}")

    resultados_por_gap[gap_weeks] = pd.DataFrame(resultados)
    predicciones_por_gap[gap_weeks] = pd.concat(predicciones_todas, ignore_index=True) if predicciones_todas else pd.DataFrame()

# GUARDAR EN EXCEL CON HOJAS SEPARADAS POR GAP 
with pd.ExcelWriter("resultados_prophet_por_gap_P_noinvierte.xlsx", engine="openpyxl") as writer:
    for gap_weeks in resultados_por_gap:
        hoja_metricas = f"Metricas_gap{gap_weeks}"
        hoja_preds = f"Predicciones_gap{gap_weeks}"
        resultados_por_gap[gap_weeks].to_excel(writer, sheet_name=hoja_metricas, index=False)
        predicciones_por_gap[gap_weeks].to_excel(writer, sheet_name=hoja_preds, index=False)

print(" Resultados guardados por hoja según gap.")
# Out:
# 21:51:41 - cmdstanpy - INFO - Chain [1] start processing
# 21:51:53 - cmdstanpy - INFO - Chain [1] done processing
# 21:51:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:52:08 - cmdstanpy - INFO - Chain [1] done processing
# 21:52:09 - cmdstanpy - INFO - Chain [1] start processing
# 21:52:21 - cmdstanpy - INFO - Chain [1] done processing
# 21:52:21 - cmdstanpy - INFO - Chain [1] start processing
# 21:52:36 - cmdstanpy - INFO - Chain [1] done processing
# 21:52:37 - cmdstanpy - INFO - Chain [1] start processing
# 21:52:47 - cmdstanpy - INFO - Chain [1] done processing
# 21:52:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:53:00 - cmdstanpy - INFO - Chain [1] done processing
# 21:53:01 - cmdstanpy - INFO - Chain [1] start processing
# 21:53:16 - cmdstanpy - INFO - Chain [1] done processing
# 21:53:17 - cmdstanpy - INFO - Chain [1] start processing
# 21:53:30 - cmdstanpy - INFO - Chain [1] done processing
# 21:53:31 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %% [markdown]
# ### Prueba festivos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os

# Crear carpeta de salida
output_dir = "resultados_prophet"
os.makedirs(output_dir, exist_ok=True)

# Función para calcular MAPE
def calcular_mape(y_true, y_pred, min_denominador=1.0):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true >= min_denominador
    if np.any(mask):
        return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
    else:
        return np.nan

# Función base Prophet con dos salidas
def ejecutar_modelo_prophet_festivos(df, columna, fecha_inicio_test, mostrar_grafico=False, ruta_guardado=None):
    df_prophet = df[['Fecha y hora', columna]].dropna().rename(columns={
        'Fecha y hora': 'ds', columna: 'y'
    })
    df_prophet['ds'] = pd.to_datetime(df_prophet['ds'])

    fecha_inicio_test = pd.to_datetime(fecha_inicio_test)
    fecha_fin_test = fecha_inicio_test + pd.Timedelta(days=1)

    fecha_fin_train_eval = fecha_inicio_test - pd.Timedelta(weeks=3)
    fecha_inicio_train = fecha_fin_train_eval - pd.Timedelta(weeks=52)
    fecha_inicio_train_eval = fecha_fin_train_eval - pd.Timedelta(days=1)

    df_test = df_prophet[(df_prophet['ds'] >= fecha_inicio_test) & (df_prophet['ds'] < fecha_fin_test)].copy()
    df_train_eval = df_prophet[(df_prophet['ds'] >= fecha_inicio_train_eval) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()
    df_train = df_prophet[(df_prophet['ds'] >= fecha_inicio_train) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()

    m = Prophet()
    m.fit(df_train)

    future = pd.concat([df_train_eval[['ds']], df_test[['ds']]]).drop_duplicates().sort_values('ds')
    forecast = m.predict(future)

    forecast_train_eval = forecast[forecast['ds'].isin(df_train_eval['ds'])]
    forecast_test = forecast[forecast['ds'].isin(df_test['ds'])]

    df_train_eval = df_train_eval.set_index('ds').join(forecast_train_eval.set_index('ds')[['yhat']], how='inner')
    df_test_eval = df_test.set_index('ds').join(forecast_test.set_index('ds')[['yhat']], how='inner')

    mae_train = mean_absolute_error(df_train_eval['y'], df_train_eval['yhat'])
    rmse_train = np.sqrt(mean_squared_error(df_train_eval['y'], df_train_eval['yhat']))
    mape_train = calcular_mape(df_train_eval['y'], df_train_eval['yhat'])

    mae_test = mean_absolute_error(df_test_eval['y'], df_test_eval['yhat'])
    rmse_test = np.sqrt(mean_squared_error(df_test_eval['y'], df_test_eval['yhat']))
    mape_test = calcular_mape(df_test_eval['y'], df_test_eval['yhat'])

    if mostrar_grafico or ruta_guardado:
        plt.figure(figsize=(12, 4))
        plt.plot(df_test_eval.index, df_test_eval['y'], label='Real')
        plt.plot(df_test_eval.index, df_test_eval['yhat'], label='Predicción')
        plt.title(f'{columna} [{fecha_inicio_test.date()}]')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()

        if ruta_guardado:
            plt.savefig(ruta_guardado)
        if mostrar_grafico:
            plt.show()
        else:
            plt.close()

    # Armar resultados de métricas
    resultados_metricas = {
        'transformador': columna,
        'fecha_inicio_test': fecha_inicio_test.date(),
        'MAE_train': mae_train, 'RMSE_train': rmse_train, 'MAPE_train': mape_train,
        'MAE_test': mae_test, 'RMSE_test': rmse_test, 'MAPE_test': mape_test
    }

    # Agregar identificador al df de predicción
    df_test_eval = df_test_eval.reset_index()
    df_test_eval['transformador'] = columna
    df_test_eval = df_test_eval.rename(columns={'y': 'real', 'yhat': 'predicho'})

    return resultados_metricas, df_test_eval

# %%
import os
import pandas as pd
import holidays
from pathlib import Path


# 1)  Carpeta donde guardar los PNG
carpeta_graficos = Path("graficos_resultados_festivos_CL")
carpeta_graficos.mkdir(exist_ok=True)


# 2) solo 2024
# FORZAR a usar solo 2024
years = [2024]
print(f"Años considerados para feriados: {years}")

# 3)  Construir feriados solo para esos años  

feriados_cl = holidays.CountryHoliday("CL", years=years)

fechas_test_por_festivo = {
    y: [pd.Timestamp(d) for d in feriados_cl if d.year == y]
    for y in years
}


# 4)  Bucle principal

resultados = []
predicciones_todas = []

for transformador in transformador_columnas_p:
    for anio, fechas in fechas_test_por_festivo.items():
        for fecha in fechas:
            #  verificación rápida de datos válidos 
            sub_df = df_transformadores[df_transformadores['Fecha y hora'].dt.date == fecha.date()]
            if sub_df[transformador].dropna().shape[0] < 2:
                print(f"Saltando {transformador}, festivo {fecha.date()}: <2 datos válidos")
                continue

            try:
                fecha_str = fecha.strftime("%Y-%m-%d")
                nombre_archivo = (
                    transformador.replace(" ", "_")
                                 .replace(".", "_")
                                 .replace("(", "")
                                 .replace(")", "")
                                 .replace("/", "_")
                )
                ruta_grafico = carpeta_graficos / f"{nombre_archivo}_{fecha_str}.png"

                resultado, predicciones_test = ejecutar_modelo_prophet_festivos(
                    df_transformadores,
                    columna=transformador,
                    fecha_inicio_test=fecha,
                    mostrar_grafico=False,
                    ruta_guardado=ruta_grafico
                )

                resultado.update({
                    "transformador": transformador,
                    "fecha_test":    fecha,
                    "festivo":       feriados_cl.get(fecha),
                    "anio":          anio
                })
                resultados.append(resultado)

                predicciones_test["fecha_test"] = fecha
                predicciones_test["festivo"]    = feriados_cl.get(fecha)
                predicciones_test["anio"]       = anio
                predicciones_todas.append(predicciones_test)

            except Exception as e:
                print(f"Error en {transformador}, festivo {fecha}: {e}")


# 5)  Consolidar resultados
df_resultados   = pd.DataFrame(resultados)
df_predicciones = pd.concat(predicciones_todas, ignore_index=True)

print(df_resultados.head())
print(df_predicciones.head())
# Out:
# Años considerados para feriados: [2024]
# 19:36:33 - cmdstanpy - INFO - Chain [1] start processing
# 19:37:11 - cmdstanpy - INFO - Chain [1] done processing
# 19:37:13 - cmdstanpy - INFO - Chain [1] start processing
# 19:37:44 - cmdstanpy - INFO - Chain [1] done processing
# 19:37:45 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:19 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:21 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:56 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:57 - cmdstanpy - INFO - Chain [1] start processing
# 19:39:28 - cmdstanpy - INFO - Chain [1] done processing
# 19:39:29 - cmdstanpy - INFO - Chain [1] start processing
# 19:39:53 - cmdstanpy - INFO - Chain [1] done processing
# 19:39:54 - cmdstanpy - INFO - Chain [1] start processing
# 19:40:15 - cmdstanpy - INFO - Chain [1] done processing
# 19:40:16 - cmdstanpy - INFO - Chain [1] start processing
# 19:40:35 - cmdstanpy - INFO - Chain [1] done processing
# ...

# %%
with pd.ExcelWriter("resultados_prophet_P_no_invierte_festivos.xlsx", engine="openpyxl") as writer:
    df_resultados.to_excel(writer, sheet_name="Metricas", index=False)
    df_predicciones.to_excel(writer, sheet_name="Predicciones", index=False)
