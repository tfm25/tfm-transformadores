# %% [markdown]
# # **Leer data transformadores**

# %%
import pandas as pd

# Lee el archivo CSV
df_transformadores = pd.read_csv('df_rellenado_con_nans.csv')

# Muestra las primeras filas del DataFrame
df_transformadores.head()
# Out:
#           Fecha y hora  \
# 0  2021-01-01 00:30:00
# 1  2021-01-01 00:45:00
# 2  2021-01-01 01:00:00
# 3  2021-01-01 01:15:00
# 4  2021-01-01 01:30:00
#
#    SE_Valparaiso.Trf_Valparaiso_T1 Potencia activa media (kW)  \
# 0                                        6657.061100
# 1                                        6600.084782
# 2                                        6579.427719
# 3                                        6523.938179
# 4                                        6389.933586
#
#    SE_Valparaiso.Trf_Valparaiso_T1 Potencia reactiva media (kVAr)  \
# 0                                         392.181486
# 1                                         370.762348
# 2                                         385.641813
# 3                                         389.757663
# 4                                         364.311010
#
#    SE_Placeres.Trf_Placeres_T1 Potencia activa media (kW)  \
# 0                                        9087.688446
# 1                                        9007.225990
# 2                                        8908.111572
# 3                                        8725.055695
# 4                                        8571.299553
#
#    SE_Placeres.Trf_Placeres_T1 Potencia reactiva media (kVAr)  \
# 0                                         -89.524969
# 1                                         -48.079155
# 2                                         -71.154483
# 3                                        -123.746052
# 4                                        -159.668446
#
#    SE_Placeres.Trf_Placeres_T2 Potencia activa media (kW)  \
# 0                                        9393.958092
# 1                                        9353.917122
# 2                                        9084.967613
# 3                                        8897.534370
# 4                                        8714.198112
#
#    SE_Placeres.Trf_Placeres_T2 Potencia reactiva media (kVAr)  \
# 0                                        1439.777136
# 1                                        1430.533409
# 2                                        1380.251646
# 3                                        1328.508615
# 4                                        1283.114433
#
#    SE_Placilla.Trf_Placilla_T2 Potencia activa media (kW)  \
# 0                                        8747.844727
# 1                                        8626.563477
# 2                                        8546.049805
# 3                                        8458.301758
# 4                                        8302.192383
#
#    SE_Placilla.Trf_Placilla_T2 Potencia reactiva media (kVAr)  \
# 0                                        -132.386734
# 1                                        -140.524490
# 2                                        -164.159393
# 3                                        -164.846237
# 4                                        -205.847855
#
#    SE_Concon.Trf_Concon_T2_2 Potencia activa media (kW)  ...  \
# 0                                        4363.275051     ...
# 1                                        4372.547626     ...
# 2                                        4297.423363     ...
# 3                                        4189.702034     ...
# 4                                        4165.856361     ...
#
#    SE_San_Rafael.Trf_San_Rafael_T3 Potencia activa media (kW)  \
# 0                                        8986.115234
# 1                                        8946.944336
# 2                                        8749.440430
# 3                                        8650.058594
# 4                                        8527.763672
#
#    SE_San_Rafael.Trf_San_Rafael_T3 Potencia reactiva media (kVAr)  \
# 0                                        1787.867920
# 1                                        1806.897827
# 2                                        1736.990967
# 3                                        1721.460083
# 4                                        1702.901367
#
#    SE_San_Felipe.Trf_San_Felipe_T1 Potencia activa media (kW)  \
# 0                                        14563.25817
# 1                                        14303.06339
# 2                                        14161.10229
# 3                                        14255.73540
# 4                                        13911.45802
#
#    SE_San_Felipe.Trf_San_Felipe_T1 Potencia reactiva media (kVAr)  \
# 0                                        1948.054075
# 1                                        2033.608913
# 2                                        2011.147261
# 3                                        2104.893208
# 4                                        1989.736915
#
#    SE_San_Felipe.Trf_San_Felipe_T2 Potencia activa media (kW)  \
# 0                                        8607.710838
# 1                                        8421.904564
# 2                                        8396.206856
# 3                                        8420.323372
# 4                                        8410.838127
#
#    SE_San_Felipe.Trf_San_Felipe_T2 Potencia reactiva media (kVAr)  \
# 0                                        1346.077800
# 1                                        1292.887449
# 2                                        1296.282291
# 3                                        1306.474209
# 4                                        1365.293384
#
#    SE_Calera.Trf_Calera_T2 Potencia activa media (kW)  \
# 0                                        7858.459949
# 1                                        7973.084927
# 2                                        7781.050682
# 3                                        7601.181507
# 4                                        7718.300819
#
#    SE_Calera.Trf_Calera_T2 Potencia reactiva media (kVAr)  estacion  \
# 0                                         467.431158         verano
# 1                                         486.736864         verano
# 2                                         708.620131         verano
# 3                                        1331.551671         verano
# 4                                        1400.925994         verano
#
#    estacion_2
# 0      verano
# 1      verano
# 2      verano
# 3      verano
# 4      verano
#
# [5 rows x 31 columns]

# %%
df_transformadores['estacion_2'].unique()
# Out:
# array(['verano', 'invierno'], dtype=object)

# %%
columnas = [
    'Fecha y hora',
    "SE_San_Rafael.Trf_San_Rafael_T1 Potencia activa media (kW)",
    "SE_San_Rafael.Trf_San_Rafael_T1 Potencia reactiva media (kVAr)",
    "SE_San_Rafael.Trf_San_Rafael_T3 Potencia activa media (kW)",
    "SE_San_Rafael.Trf_San_Rafael_T3 Potencia reactiva media (kVAr)",
    "SE_San_Felipe.Trf_San_Felipe_T1 Potencia activa media (kW)",
    "SE_San_Felipe.Trf_San_Felipe_T1 Potencia reactiva media (kVAr)",
    "SE_San_Felipe.Trf_San_Felipe_T2 Potencia activa media (kW)",
    "SE_San_Felipe.Trf_San_Felipe_T2 Potencia reactiva media (kVAr)",
    "SE_Concon.Trf_Concon_T2_2 Potencia activa media (kW)",
    "SE_Concon.Trf_Concon_T2_2 Potencia reactiva media (kVAr)",
    'estacion',
    'estacion_2'
]

df_transformadores = df_transformadores[columnas]

df_transformadores['Fecha y hora'] = pd.to_datetime(df_transformadores['Fecha y hora'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import os

transformador_columnas_p = [
 "SE_San_Rafael.Trf_San_Rafael_T1 Potencia activa media (kW)",
 "SE_San_Rafael.Trf_San_Rafael_T3 Potencia activa media (kW)",
 "SE_San_Felipe.Trf_San_Felipe_T1 Potencia activa media (kW)",
 "SE_San_Felipe.Trf_San_Felipe_T2 Potencia activa media (kW)", 
 "SE_Concon.Trf_Concon_T2_2 Potencia activa media (kW)"
]
    

transformador_columnas_q = [
 "SE_San_Rafael.Trf_San_Rafael_T1 Potencia reactiva media (kVAr)", 
 "SE_San_Rafael.Trf_San_Rafael_T3 Potencia reactiva media (kVAr)", 
 "SE_San_Felipe.Trf_San_Felipe_T1 Potencia reactiva media (kVAr)",
 "SE_San_Felipe.Trf_San_Felipe_T2 Potencia reactiva media (kVAr)",
"SE_Concon.Trf_Concon_T2_2 Potencia reactiva media (kVAr)"
]

# %%
# Unir ambas listas de columnas
columnas_a_convertir = transformador_columnas_p + transformador_columnas_q

# Aplicar la conversión: dividir por 1000
df_transformadores[columnas_a_convertir] = df_transformadores[columnas_a_convertir] / 1000

# %%
df_transformadores.head()
# Out:
#          Fecha y hora  \
# 0 2021-01-01 00:30:00
# 1 2021-01-01 00:45:00
# 2 2021-01-01 01:00:00
# 3 2021-01-01 01:15:00
# 4 2021-01-01 01:30:00
#
#    SE_San_Rafael.Trf_San_Rafael_T1 Potencia activa media (kW)  \
# 0                                          12.940086
# 1                                          12.640568
# 2                                          12.424030
# 3                                          12.373395
# 4                                          12.171638
#
#    SE_San_Rafael.Trf_San_Rafael_T1 Potencia reactiva media (kVAr)  \
# 0                                           3.649591
# 1                                           3.558793
# 2                                           3.533698
# 3                                           3.551495
# 4                                           3.438511
#
#    SE_San_Rafael.Trf_San_Rafael_T3 Potencia activa media (kW)  \
# 0                                           8.986115
# 1                                           8.946944
# 2                                           8.749440
# 3                                           8.650059
# 4                                           8.527764
#
#    SE_San_Rafael.Trf_San_Rafael_T3 Potencia reactiva media (kVAr)  \
# 0                                           1.787868
# 1                                           1.806898
# 2                                           1.736991
# 3                                           1.721460
# 4                                           1.702901
#
#    SE_San_Felipe.Trf_San_Felipe_T1 Potencia activa media (kW)  \
# 0                                          14.563258
# 1                                          14.303063
# 2                                          14.161102
# 3                                          14.255735
# 4                                          13.911458
#
#    SE_San_Felipe.Trf_San_Felipe_T1 Potencia reactiva media (kVAr)  \
# 0                                           1.948054
# 1                                           2.033609
# 2                                           2.011147
# 3                                           2.104893
# 4                                           1.989737
#
#    SE_San_Felipe.Trf_San_Felipe_T2 Potencia activa media (kW)  \
# 0                                           8.607711
# 1                                           8.421905
# 2                                           8.396207
# 3                                           8.420323
# 4                                           8.410838
#
#    SE_San_Felipe.Trf_San_Felipe_T2 Potencia reactiva media (kVAr)  \
# 0                                           1.346078
# 1                                           1.292887
# 2                                           1.296282
# 3                                           1.306474
# 4                                           1.365293
#
#    SE_Concon.Trf_Concon_T2_2 Potencia activa media (kW)  \
# 0                                           4.363275
# 1                                           4.372548
# 2                                           4.297423
# 3                                           4.189702
# 4                                           4.165856
#
#    SE_Concon.Trf_Concon_T2_2 Potencia reactiva media (kVAr) estacion  \
# 0                                           0.705140          verano
# 1                                           0.669971          verano
# 2                                           0.676845          verano
# 3                                           0.644257          verano
# 4                                           0.633751          verano
#
#   estacion_2
# 0     verano
# 1     verano
# 2     verano
# 3     verano
# 4     verano

# %%
df_transformadores['Fecha y hora'] = pd.to_datetime(df_transformadores['Fecha y hora'])

# Mostrar la fecha mínima y máxima
fecha_min = df_transformadores['Fecha y hora'].min()
fecha_max = df_transformadores['Fecha y hora'].max()

print("Fecha mínima:", fecha_min)
print("Fecha máxima:", fecha_max)
# Out:
# Fecha mínima: 2021-01-01 00:30:00
# Fecha máxima: 2025-04-21 00:00:00

# %%
# Definir las fechas de inicio y fin
fecha_inicio = pd.to_datetime('2022-09-01 00:00:00')
fecha_fin = pd.to_datetime('2025-04-08 00:00:00')

# Filtrar el DataFrame para que solo contenga registros entre fecha_inicio y fecha_fin
df_transformadores = df_transformadores[(df_transformadores['Fecha y hora'] >= fecha_inicio) & (df_transformadores['Fecha y hora'] <= fecha_fin)]

# %%
df_transformadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91201 entries, 58366 to 149566
# Data columns (total 13 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Fecha y hora                                                    91201 non-null  datetime64[ns]
#  1   SE_San_Rafael.Trf_San_Rafael_T1 Potencia activa media (kW)      91201 non-null  float64
#  2   SE_San_Rafael.Trf_San_Rafael_T1 Potencia reactiva media (kVAr)  91201 non-null  float64
#  3   SE_San_Rafael.Trf_San_Rafael_T3 Potencia activa media (kW)      91201 non-null  float64
#  4   SE_San_Rafael.Trf_San_Rafael_T3 Potencia reactiva media (kVAr)  91201 non-null  float64
#  5   SE_San_Felipe.Trf_San_Felipe_T1 Potencia activa media (kW)      91201 non-null  float64
#  6   SE_San_Felipe.Trf_San_Felipe_T1 Potencia reactiva media (kVAr)  91201 non-null  float64
#  7   SE_San_Felipe.Trf_San_Felipe_T2 Potencia activa media (kW)      91201 non-null  float64
#  8   SE_San_Felipe.Trf_San_Felipe_T2 Potencia reactiva media (kVAr)  91201 non-null  float64
#  9   SE_Concon.Trf_Concon_T2_2 Potencia activa media (kW)            91201 non-null  float64
#  10  SE_Concon.Trf_Concon_T2_2 Potencia reactiva media (kVAr)        91201 non-null  float64
#  11  estacion                                                        91201 non-null  object
#  12  estacion_2                                                      91201 non-null  object
# dtypes: datetime64[ns](1), float64(10), object(2)
# memory usage: 9.7+ MB

# %% [markdown]
# # **Instalación de librerias**

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /opt/anaconda3/lib/python3.12/site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (3.9.2)
# Requirement already satisfied: pandas>=1.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (0.70)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (4.66.5)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/lib/python3.12/site-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.12/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)

# %%
from prophet import Prophet
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # **Modelos Invierten Q**

# %%
def calcular_mape(y_true, y_pred, min_denominador=1.0):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true >= min_denominador
    if np.any(mask):
        return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
    else:
        return np.nan

# %% [markdown]
# ## Estacionalidades manuales 3 años de data

# %%
def ejecutar_modelo_prophet_parametros_estacion_manual(df, columna, fecha_inicio_test, mostrar_grafico=False, ruta_guardado=None):
    # Preparar datos
    df_prophet = df[['Fecha y hora', columna, 'estacion']].dropna().rename(columns={
        'Fecha y hora': 'ds', columna: 'y'
    })
    df_prophet['ds'] = pd.to_datetime(df_prophet['ds'])

    # Convertir 'estacion' en dummies
    df_prophet = pd.get_dummies(df_prophet, columns=['estacion'], prefix='est')
    columnas_estacion = [col for col in df_prophet.columns if col.startswith('est_')]

    # Fechas clave
    fecha_inicio_test = pd.to_datetime(fecha_inicio_test)
    fecha_fin_test = fecha_inicio_test + pd.Timedelta(days=7)
    fecha_fin_train_eval = fecha_inicio_test - pd.Timedelta(minutes=15)
    fecha_inicio_train_eval = fecha_fin_train_eval - pd.Timedelta(weeks=1) + pd.Timedelta(minutes=15)

    # Filtrar conjuntos
    df_test = df_prophet[(df_prophet['ds'] >= fecha_inicio_test) & (df_prophet['ds'] < fecha_fin_test)].copy()
    df_train_eval = df_prophet[(df_prophet['ds'] >= fecha_inicio_train_eval) & (df_prophet['ds'] < fecha_fin_train_eval)].copy()
    df_train = df_prophet[df_prophet['ds'] <= fecha_fin_train_eval].copy()

    # Crear y configurar el modelo
    m = Prophet(
        daily_seasonality=False,
        weekly_seasonality=False,
        yearly_seasonality=False,
        n_changepoints=50
    )
    m.add_seasonality(name='daily_hour', period=1, fourier_order=20)
    m.add_seasonality(name='weekly_custom', period=7, fourier_order=30)
    m.add_seasonality(name='yearly_custom', period=365.25, fourier_order=10)

    for col in columnas_estacion:
        m.add_regressor(col)

    # Entrenamiento
    m.fit(df_train)

    # Preparar fechas futuras
    future = pd.concat([df_train_eval[['ds']], df_test[['ds']]]).drop_duplicates().sort_values('ds')
    future = future.merge(df_prophet[['ds'] + columnas_estacion], on='ds', how='left')

    # Predicción
    forecast = m.predict(future)
    forecast_train_eval = forecast[forecast['ds'].isin(df_train_eval['ds'])]
    forecast_test = forecast[forecast['ds'].isin(df_test['ds'])]

    df_train_eval = df_train_eval.set_index('ds').join(forecast_train_eval.set_index('ds')[['yhat']], how='inner')
    df_test_eval = df_test.set_index('ds').join(forecast_test.set_index('ds')[['yhat']], how='inner')

    # Métricas
    mae_train = mean_absolute_error(df_train_eval['y'], df_train_eval['yhat'])
    rmse_train = np.sqrt(mean_squared_error(df_train_eval['y'], df_train_eval['yhat']))
    mape_train = calcular_mape(df_train_eval['y'], df_train_eval['yhat'])

    mae_test = mean_absolute_error(df_test_eval['y'], df_test_eval['yhat'])
    rmse_test = np.sqrt(mean_squared_error(df_test_eval['y'], df_test_eval['yhat']))
    mape_test = calcular_mape(df_test_eval['y'], df_test_eval['yhat'])

    # Gráfico opcional
    if mostrar_grafico or ruta_guardado:
        plt.figure(figsize=(12, 4))
        plt.plot(df_test_eval.index, df_test_eval['y'], label='Real')
        plt.plot(df_test_eval.index, df_test_eval['yhat'], label='Predicción')
        plt.title(f'{columna} [{fecha_inicio_test.date()}]')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()

        if ruta_guardado:
            plt.savefig(ruta_guardado)
        if mostrar_grafico:
            plt.show()
        else:
            plt.close()

    # Armar resultados de métricas
    resultados_metricas = {
        'transformador': columna,
        'fecha_inicio_test': fecha_inicio_test.date(),
        'MAE_train': mae_train, 'RMSE_train': rmse_train, 'MAPE_train': mape_train,
        'MAE_test': mae_test, 'RMSE_test': rmse_test, 'MAPE_test': mape_test
    }

    # Preparar df_test_eval para exportar
    df_test_eval = df_test_eval.reset_index()
    df_test_eval['transformador'] = columna
    df_test_eval = df_test_eval.rename(columns={'y': 'real', 'yhat': 'predicho'})

    return resultados_metricas, df_test_eval

# %%
from datetime import timedelta
from pandas import Timestamp

# Define estaciones según hemisferio sur
estaciones_meses = {
    'primavera': [9, 10, 11],
    'verano': [12, 1, 2],
    'otoño': [3, 4, 5],
    'invierno': [6, 7, 8]
}

# Fechas límites
inicio_data = pd.to_datetime("2023-06-24")
fin_data = pd.to_datetime("2025-04-02")
duracion_entrenamiento = timedelta(weeks=52)
gap = timedelta(weeks=2)
duracion_test = timedelta(days=7)

# Extraer fechas candidatas desde la columna 'Fecha y hora'
fechas_disponibles = pd.Series(pd.to_datetime(df_transformadores["Fecha y hora"].dropna().unique()))
fechas_disponibles = fechas_disponibles.sort_values()


def seleccionar_fechas_test(estacion, meses_objetivo, cantidad=4, min_dias_entre_fechas=21):
    candidatos = []
    fechas_filtradas = fechas_disponibles[
        (fechas_disponibles.dt.weekday == 0) &  # lunes
        (fechas_disponibles.dt.hour == 0) &     # a las 00:00
        (fechas_disponibles.dt.minute == 0) &   # y minuto 00
        (fechas_disponibles.dt.month.isin(meses_objetivo))
    ].sort_values(ascending=False)  # orden descendente

    for fecha in fechas_filtradas:
        # Validar que haya suficiente data de entrenamiento
        inicio_entrenamiento = fecha - gap - duracion_entrenamiento
        if inicio_entrenamiento < inicio_data or (fecha + duracion_test) > fin_data:
            continue
        # Evitar semanas muy cercanas entre sí
        if any(abs((fecha - f).days) < min_dias_entre_fechas for f in candidatos):
            continue
        candidatos.append(fecha)
        if len(candidatos) == cantidad:
            break
    return candidatos


# Armar el diccionario completo
fechas_test_por_estacion = {
    estacion: seleccionar_fechas_test(estacion, meses)
    for estacion, meses in estaciones_meses.items()
}

fechas_test_por_estacion['otoño'].append(Timestamp('2024-03-17 00:00:00'))

print(fechas_test_por_estacion)
# Out:
# {'primavera': [Timestamp('2024-11-25 00:00:00'), Timestamp('2024-11-04 00:00:00'), Timestamp('2024-10-14 00:00:00'), Timestamp('2024-09-23 00:00:00')], 'verano': [Timestamp('2025-02-24 00:00:00'), Timestamp('2025-02-03 00:00:00'), Timestamp('2025-01-13 00:00:00'), Timestamp('2024-12-23 00:00:00')], 'otoño': [Timestamp('2025-03-24 00:00:00'), Timestamp('2025-03-03 00:00:00'), Timestamp('2024-03-17 00:00:00')], 'invierno': [Timestamp('2024-08-26 00:00:00'), Timestamp('2024-08-05 00:00:00'), Timestamp('2024-07-15 00:00:00')]}

# %%
# Crear carpeta para guardar gráficos si no existe
carpeta_graficos = "graficos_resultados_1_año"
os.makedirs(carpeta_graficos, exist_ok=True)

# Listas para acumular resultados
resultados = []
predicciones_todas = []

# Bucle principal
for transformador in transformador_columnas_q:
    for estacion, fechas in fechas_test_por_estacion.items():
        for fecha in fechas:
            try:
                # Formatear fecha para nombre de archivo
                fecha_str = fecha.strftime("%Y-%m-%d_%H-%M")

                # Limpiar nombre del transformador para archivo
                nombre_archivo = (
                    transformador.replace(" ", "_")
                    .replace(".", "_")
                    .replace("(", "")
                    .replace(")", "")
                    .replace("/", "_")
                )
                ruta_grafico = os.path.join(carpeta_graficos, f"{nombre_archivo}_{fecha_str}.png")

                # Ejecutar modelo (ahora retorna dos cosas)
                resultado, predicciones_test = ejecutar_modelo_prophet_parametros_estacion_manual(
                    df_transformadores, 
                    columna=transformador, 
                    fecha_inicio_test=fecha, 
                    mostrar_grafico=False,
                    ruta_guardado=ruta_grafico
                )

                # Agregar información contextual a ambos outputs
                resultado["transformador"] = transformador
                resultado["fecha_test"] = fecha
                resultado["estacion"] = estacion
                resultados.append(resultado)

                predicciones_test["fecha_test"] = fecha
                predicciones_test["estacion"] = estacion
                predicciones_todas.append(predicciones_test)

            except Exception as e:
                print(f"Error en {transformador}, {fecha}: {e}")

# Convertir a DataFrame los resultados
df_resultados = pd.DataFrame(resultados)
df_predicciones = pd.concat(predicciones_todas, ignore_index=True)

# Mostrar (o guardar si lo deseas)
print(df_resultados.head())
print(df_predicciones.head())
# Out:
# 20:10:13 - cmdstanpy - INFO - Chain [1] start processing
# 20:12:28 - cmdstanpy - INFO - Chain [1] done processing
# 20:12:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:14:12 - cmdstanpy - INFO - Chain [1] done processing
# 20:14:16 - cmdstanpy - INFO - Chain [1] start processing
# 20:16:15 - cmdstanpy - INFO - Chain [1] done processing
# 20:16:18 - cmdstanpy - INFO - Chain [1] start processing
# 20:18:14 - cmdstanpy - INFO - Chain [1] done processing
# 20:18:17 - cmdstanpy - INFO - Chain [1] start processing
# 20:21:14 - cmdstanpy - INFO - Chain [1] done processing
# 20:21:18 - cmdstanpy - INFO - Chain [1] start processing
# 20:23:38 - cmdstanpy - INFO - Chain [1] done processing
# 20:23:42 - cmdstanpy - INFO - Chain [1] start processing
# 20:26:56 - cmdstanpy - INFO - Chain [1] done processing
# 20:27:00 - cmdstanpy - INFO - Chain [1] start processing
# 20:29:29 - cmdstanpy - INFO - Chain [1] done processing
# 20:29:32 - cmdstanpy - INFO - Chain [1] start processing
# 20:32:16 - cmdstanpy - INFO - Chain [1] done processing
# 20:32:20 - cmdstanpy - INFO - Chain [1] start processing
# 20:34:01 - cmdstanpy - INFO - Chain [1] done processing
# 20:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 20:34:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:34:50 - cmdstanpy - INFO - Chain [1] start processing
# 20:36:52 - cmdstanpy - INFO - Chain [1] done processing
# 20:36:55 - cmdstanpy - INFO - Chain [1] start processing
# 20:38:16 - cmdstanpy - INFO - Chain [1] done processing
# 20:38:19 - cmdstanpy - INFO - Chain [1] start processing
# 20:39:20 - cmdstanpy - INFO - Chain [1] done processing
# 20:39:23 - cmdstanpy - INFO - Chain [1] start processing
# 20:39:44 - cmdstanpy - INFO - Chain [1] done processing
# 20:39:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:40:12 - cmdstanpy - INFO - Chain [1] done processing
# 20:40:15 - cmdstanpy - INFO - Chain [1] start processing
# 20:40:44 - cmdstanpy - INFO - Chain [1] done processing
# 20:40:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:41:08 - cmdstanpy - INFO - Chain [1] done processing
# 20:41:11 - cmdstanpy - INFO - Chain [1] start processing
# 20:41:45 - cmdstanpy - INFO - Chain [1] done processing
# 20:41:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:42:16 - cmdstanpy - INFO - Chain [1] done processing
# 20:42:19 - cmdstanpy - INFO - Chain [1] start processing
# 20:42:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:42:51 - cmdstanpy - INFO - Chain [1] start processing
# 20:43:19 - cmdstanpy - INFO - Chain [1] done processing
# 20:43:23 - cmdstanpy - INFO - Chain [1] start processing
# 20:44:00 - cmdstanpy - INFO - Chain [1] done processing
# 20:44:03 - cmdstanpy - INFO - Chain [1] start processing
# 20:44:33 - cmdstanpy - INFO - Chain [1] done processing
# 20:44:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:44:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:44:50 - cmdstanpy - INFO - Chain [1] start processing
# 20:45:03 - cmdstanpy - INFO - Chain [1] done processing
# 20:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 20:45:18 - cmdstanpy - INFO - Chain [1] done processing
# 20:45:20 - cmdstanpy - INFO - Chain [1] start processing
# 20:45:34 - cmdstanpy - INFO - Chain [1] done processing
# 20:45:37 - cmdstanpy - INFO - Chain [1] start processing
# 20:46:29 - cmdstanpy - INFO - Chain [1] done processing
# 20:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 20:47:14 - cmdstanpy - INFO - Chain [1] done processing
# 20:47:17 - cmdstanpy - INFO - Chain [1] start processing
# 20:47:33 - cmdstanpy - INFO - Chain [1] done processing
# 20:47:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:48:04 - cmdstanpy - INFO - Chain [1] done processing
# 20:48:07 - cmdstanpy - INFO - Chain [1] start processing
# 20:49:14 - cmdstanpy - INFO - Chain [1] done processing
# 20:49:18 - cmdstanpy - INFO - Chain [1] start processing
# 20:50:42 - cmdstanpy - INFO - Chain [1] done processing
# 20:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:51:19 - cmdstanpy - INFO - Chain [1] done processing
# 20:51:22 - cmdstanpy - INFO - Chain [1] start processing
# 20:52:05 - cmdstanpy - INFO - Chain [1] done processing
# 20:52:08 - cmdstanpy - INFO - Chain [1] start processing
# 20:53:03 - cmdstanpy - INFO - Chain [1] done processing
# 20:53:06 - cmdstanpy - INFO - Chain [1] start processing
# 20:54:12 - cmdstanpy - INFO - Chain [1] done processing
# 20:54:15 - cmdstanpy - INFO - Chain [1] start processing
# 20:54:44 - cmdstanpy - INFO - Chain [1] done processing
# 20:54:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:55:18 - cmdstanpy - INFO - Chain [1] done processing
# 20:55:20 - cmdstanpy - INFO - Chain [1] start processing
# 20:56:04 - cmdstanpy - INFO - Chain [1] done processing
# 20:56:07 - cmdstanpy - INFO - Chain [1] start processing
# 20:56:40 - cmdstanpy - INFO - Chain [1] done processing
# 20:56:43 - cmdstanpy - INFO - Chain [1] start processing
# 20:57:43 - cmdstanpy - INFO - Chain [1] done processing
# 20:57:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:01 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:19 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:21 - cmdstanpy - INFO - Chain [1] start processing
# 21:01:04 - cmdstanpy - INFO - Chain [1] done processing
# 21:01:07 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:13 - cmdstanpy - INFO - Chain [1] done processing
# 21:02:16 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:33 - cmdstanpy - INFO - Chain [1] done processing
# 21:03:36 - cmdstanpy - INFO - Chain [1] start processing
# 21:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 21:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 21:06:54 - cmdstanpy - INFO - Chain [1] done processing
# 21:06:58 - cmdstanpy - INFO - Chain [1] start processing
# 21:08:16 - cmdstanpy - INFO - Chain [1] done processing
# 21:08:20 - cmdstanpy - INFO - Chain [1] start processing
# 21:09:47 - cmdstanpy - INFO - Chain [1] done processing
# 21:09:50 - cmdstanpy - INFO - Chain [1] start processing
# 21:10:11 - cmdstanpy - INFO - Chain [1] done processing
# 21:10:14 - cmdstanpy - INFO - Chain [1] start processing
# 21:11:01 - cmdstanpy - INFO - Chain [1] done processing
# 21:11:03 - cmdstanpy - INFO - Chain [1] start processing
# 21:12:13 - cmdstanpy - INFO - Chain [1] done processing
# 21:12:16 - cmdstanpy - INFO - Chain [1] start processing
# 21:13:00 - cmdstanpy - INFO - Chain [1] done processing
# 21:13:03 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:16 - cmdstanpy - INFO - Chain [1] done processing
# 21:14:18 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:38 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:41 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:29 - cmdstanpy - INFO - Chain [1] done processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:19:34 - cmdstanpy - INFO - Chain [1] done processing
# 21:19:38 - cmdstanpy - INFO - Chain [1] start processing
# 21:21:19 - cmdstanpy - INFO - Chain [1] done processing
# 21:21:22 - cmdstanpy - INFO - Chain [1] start processing
# 21:22:59 - cmdstanpy - INFO - Chain [1] done processing
# 21:23:03 - cmdstanpy - INFO - Chain [1] start processing
# 21:24:08 - cmdstanpy - INFO - Chain [1] done processing
# 21:24:11 - cmdstanpy - INFO - Chain [1] start processing
# 21:25:08 - cmdstanpy - INFO - Chain [1] done processing
# 21:25:11 - cmdstanpy - INFO - Chain [1] start processing
# 21:25:54 - cmdstanpy - INFO - Chain [1] done processing
# 21:25:58 - cmdstanpy - INFO - Chain [1] start processing
# 21:27:39 - cmdstanpy - INFO - Chain [1] done processing
# 21:27:41 - cmdstanpy - INFO - Chain [1] start processing
# 21:29:11 - cmdstanpy - INFO - Chain [1] done processing
# 21:29:13 - cmdstanpy - INFO - Chain [1] start processing
# 21:30:34 - cmdstanpy - INFO - Chain [1] done processing
# 21:30:37 - cmdstanpy - INFO - Chain [1] start processing
# 21:32:38 - cmdstanpy - INFO - Chain [1] done processing
# 21:32:41 - cmdstanpy - INFO - Chain [1] start processing
# 21:34:38 - cmdstanpy - INFO - Chain [1] done processing
#                                        transformador fecha_inicio_test  \
# 0  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...        2024-11-25
# 1  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...        2024-11-04
# 2  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...        2024-10-14
# 3  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...        2024-09-23
# 4  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...        2025-02-24
#
#    MAE_train  RMSE_train  MAPE_train  MAE_test  RMSE_test  MAPE_test  \
# 0   1.198579    1.470197   39.386745  1.286087   1.358053  51.413104
# 1   1.209159    1.446528   38.936424  1.156881   1.314660  35.816135
# 2   0.760777    1.047897   44.189291  1.001205   1.498153  25.048690
# 3   0.792976    1.127501   54.427413  0.908559   1.039249  44.535909
# 4   0.468639    0.548219   18.041610  0.378978   0.531385  10.283105
#
#   fecha_test   estacion
# 0 2024-11-25  primavera
# 1 2024-11-04  primavera
# 2 2024-10-14  primavera
# 3 2024-09-23  primavera
# 4 2025-02-24     verano
#                    ds      real  est_invierno  est_otoño  est_primavera  \
# 0 2024-11-25 00:00:00  2.064967         False      False           True
# 1 2024-11-25 00:15:00  1.953412         False      False           True
# 2 2024-11-25 00:30:00  1.766805         False      False           True
# 3 2024-11-25 00:45:00  1.773500         False      False           True
# 4 2024-11-25 01:00:00  1.804612         False      False           True
#
#    est_verano  predicho                                      transformador  \
# 0       False  3.153005  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...
# 1       False  3.119888  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...
# 2       False  3.096288  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...
# 3       False  3.067154  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...
# 4       False  3.030027  SE_San_Rafael.Trf_San_Rafael_T1 Potencia react...
#
#   fecha_test   estacion
# 0 2024-11-25  primavera
# 1 2024-11-25  primavera
# 2 2024-11-25  primavera
# 3 2024-11-25  primavera
# 4 2024-11-25  primavera

# %%
# Convertir a DataFrame los resultados
df_resultados = pd.DataFrame(resultados)
df_predicciones = pd.concat(predicciones_todas, ignore_index=True)

# Mostrar (o guardar si lo deseas)
print(df_resultados.head())
print(df_predicciones.head())
# Out:
#                                        transformador fecha_inicio_test  \
# 0  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...        2024-11-25
# 1  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...        2024-11-04
# 2  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...        2025-02-24
# 3  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...        2025-02-03
# 4  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...        2025-03-24
#
#    gap_semanas  MAE_train  RMSE_train  MAPE_train  MAE_test  RMSE_test  \
# 0           12   3.178580    4.585248   20.510438  4.465890   5.247846
# 1           12   3.144932    4.105044   25.019773  9.200514  10.161124
# 2           12   3.597059    3.913346   45.337126  4.969161   5.527996
# 3           12   3.711629    4.263078   40.039915  4.362463   4.796817
# 4           12   2.970072    3.462568   40.051993  2.852529   3.659978
#
#    MAPE_test fecha_test   estacion
# 0  73.378810 2024-11-25  primavera
# 1  91.735480 2024-11-04  primavera
# 2  82.739521 2025-02-24     verano
# 3  64.829661 2025-02-03     verano
# 4  36.656575 2025-03-24      otoño
#                    ds       real  est_invierno  est_otoño  est_primavera  \
# 0 2024-11-25 00:00:00  11.080289         False      False           True
# 1 2024-11-25 00:15:00  10.758238         False      False           True
# 2 2024-11-25 00:30:00  10.307382         False      False           True
# 3 2024-11-25 00:45:00  10.033526         False      False           True
# 4 2024-11-25 01:00:00   9.729985         False      False           True
#
#    est_verano  predicho                                      transformador  \
# 0       False  4.167058  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...
# 1       False  3.703323  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...
# 2       False  3.236069  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...
# 3       False  2.788241  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...
# 4       False  2.375671  SE_San_Rafael.Trf_San_Rafael_T1 Potencia activ...
#
#   fecha_test   estacion  gap_semanas
# 0 2024-11-25  primavera           12
# 1 2024-11-25  primavera           12
# 2 2024-11-25  primavera           12
# 3 2024-11-25  primavera           12
# 4 2024-11-25  primavera           12

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
with pd.ExcelWriter("resultados_prophet_completos_invierten_Q_sin_gap.xlsx", engine="openpyxl") as writer:
    df_resultados.to_excel(writer, sheet_name="Metricas", index=False)
    df_predicciones.to_excel(writer, sheet_name="Predicciones", index=False)

# %% [markdown]
# ## Prueba de estres

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
from datetime import timedelta
import os

# === RUTAS DE SALIDA ===
output_dir = "resultados_prophet_estacional_gap_q"
carpeta_graficos = "graficos_estacional_gap_q"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(carpeta_graficos, exist_ok=True)

# === FUNCIÓN MAPE ===
def calcular_mape(y_true, y_pred, min_denominador=1.0):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true >= min_denominador
    return (
        np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
        if np.any(mask)
        else np.nan
    )

# === PROPHET CON DUMMIES DE ESTACIÓN Y GAP VARIABLE ===
def ejecutar_modelo_prophet_parametros_estacion_manual(
    df,
    columna,
    fecha_inicio_test,
    gap_weeks=0,
    mostrar_grafico=False,
    ruta_guardado=None,
):
    df_prophet = (
        df[["Fecha y hora", columna, "estacion"]]
        .dropna()
        .rename(columns={"Fecha y hora": "ds", columna: "y"})
    )
    df_prophet["ds"] = pd.to_datetime(df_prophet["ds"])
    df_prophet = pd.get_dummies(df_prophet, columns=["estacion"], prefix="est")
    columnas_estacion = [c for c in df_prophet.columns if c.startswith("est_")]

    fecha_inicio_test = pd.to_datetime(fecha_inicio_test)
    fecha_fin_test = fecha_inicio_test + timedelta(days=7)

    # Fin de train/validación inmediatamente antes del gap
    fecha_fin_train_eval = fecha_inicio_test - timedelta(weeks=gap_weeks, minutes=15)
    # Semana de validación
    fecha_inicio_train_eval = fecha_fin_train_eval - timedelta(weeks=1) + timedelta(
        minutes=15
    )

    # TEST (1 semana)
    df_test = df_prophet[
        (df_prophet["ds"] >= fecha_inicio_test) & (df_prophet["ds"] < fecha_fin_test)
    ].copy()

    # VALIDACIÓN (1 semana antes del gap)
    df_train_eval = df_prophet[
        (df_prophet["ds"] >= fecha_inicio_train_eval)
        & (df_prophet["ds"] < fecha_fin_train_eval)
    ].copy()

    # TRAIN = TODO lo anterior a fecha_fin_train_eval
    df_train = df_prophet[df_prophet["ds"] <= fecha_fin_train_eval].copy()

    # ======= Prophet =======
    m = Prophet(
        daily_seasonality=False,
        weekly_seasonality=False,
        yearly_seasonality=False,
        n_changepoints=50,
    )
    m.add_seasonality(name="daily_hour", period=1, fourier_order=20)
    m.add_seasonality(name="weekly_custom", period=7, fourier_order=30)
    m.add_seasonality(name="yearly_custom", period=365.25, fourier_order=10)

    for col in columnas_estacion:
        m.add_regressor(col)

    m.fit(df_train)

    # ======= Predicción =======
    future = (
        pd.concat([df_train_eval[["ds"]], df_test[["ds"]]])
        .drop_duplicates()
        .sort_values("ds")
        .merge(df_prophet[["ds"] + columnas_estacion], on="ds", how="left")
    )
    forecast = m.predict(future)

    forecast_train_eval = forecast[forecast["ds"].isin(df_train_eval["ds"])]
    forecast_test = forecast[forecast["ds"].isin(df_test["ds"])]

    df_train_eval = df_train_eval.set_index("ds").join(
        forecast_train_eval.set_index("ds")[["yhat"]], how="inner"
    )
    df_test_eval = df_test.set_index("ds").join(
        forecast_test.set_index("ds")[["yhat"]], how="inner"
    )

    # ======= Métricas =======
    mae_train = mean_absolute_error(df_train_eval["y"], df_train_eval["yhat"])
    rmse_train = np.sqrt(mean_squared_error(df_train_eval["y"], df_train_eval["yhat"]))
    mape_train = calcular_mape(df_train_eval["y"], df_train_eval["yhat"])

    mae_test = mean_absolute_error(df_test_eval["y"], df_test_eval["yhat"])
    rmse_test = np.sqrt(mean_squared_error(df_test_eval["y"], df_test_eval["yhat"]))
    mape_test = calcular_mape(df_test_eval["y"], df_test_eval["yhat"])

    # ======= Gráfico =======
    if mostrar_grafico or ruta_guardado:
        plt.figure(figsize=(12, 4))
        plt.plot(df_test_eval.index, df_test_eval["y"], label="Real")
        plt.plot(df_test_eval.index, df_test_eval["yhat"], label="Predicción")
        plt.title(f"{columna} [{fecha_inicio_test.date()}] – gap {gap_weeks} sem")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        if ruta_guardado:
            plt.savefig(ruta_guardado)
        if mostrar_grafico:
            plt.show()
        else:
            plt.close()

    resultados_metricas = {
        "transformador": columna,
        "fecha_inicio_test": fecha_inicio_test.date(),
        "gap_semanas": gap_weeks,
        "MAE_train": mae_train,
        "RMSE_train": rmse_train,
        "MAPE_train": mape_train,
        "MAE_test": mae_test,
        "RMSE_test": rmse_test,
        "MAPE_test": mape_test,
    }

    df_test_eval = (
        df_test_eval.reset_index()
        .rename(columns={"y": "real", "yhat": "predicho"})
        .assign(transformador=columna)
    )

    return resultados_metricas, df_test_eval


# === PARAMETRIZACIÓN PARA LAS PRUEBAS DE STRESS ===
inicio_data = pd.to_datetime("2022-09-01")  # fecha mínima que tienes en el dataset
fin_data = pd.to_datetime("2025-04-02")     # fecha máxima que vas a usar
duracion_test = timedelta(days=7)           # 1 semana de test

estaciones_meses = {
    "primavera": [9, 10, 11],
    "verano": [12, 1, 2],
    "otoño": [3, 4, 5],
    "invierno": [6, 7, 8],
}

# Serie con todos los timestamps únicos (para seleccionar lunes 00:00)
fechas_disponibles = (
    pd.Series(pd.to_datetime(df_transformadores["Fecha y hora"].dropna().unique()))
    .sort_values()
)

def seleccionar_fechas_test(
    meses_objetivo, gap_weeks, cantidad=2, min_dias_entre_fechas=21
):
    """
    Devuelve 'cantidad' fechas de inicio de test (lunes 00:00) por estación y gap,
    asegurando que:
      • haya datos al menos hasta `inicio_data`
      • el test completo esté dentro de los datos
      • las fechas queden separadas ≥ min_dias_entre_fechas
    """
    candidatos = []
    fechas_filtradas = fechas_disponibles[
        (fechas_disponibles.dt.weekday == 0)
        & (fechas_disponibles.dt.hour == 0)
        & (fechas_disponibles.dt.minute == 0)
        & (fechas_disponibles.dt.month.isin(meses_objetivo))
    ].sort_values(ascending=False)

    for fecha in fechas_filtradas:
        # Fin de entrenamiento/validación (antes del gap)
        fecha_fin_train_eval = fecha - timedelta(weeks=gap_weeks)
        # Verifica que haya *algo* de historial
        if fecha_fin_train_eval <= inicio_data:
            continue
        # Verifica que el test completo quede dentro de los datos
        if (fecha + duracion_test) > fin_data:
            continue
        # Verifica separación mínima entre tests
        if any(abs((fecha - f).days) < min_dias_entre_fechas for f in candidatos):
            continue

        candidatos.append(fecha)
        if len(candidatos) == cantidad:
            break
    return candidatos


# === EJECUCIÓN DE LOS EXPERIMENTOS Y EXPORTACIÓN ===
resultados_por_gap = {}
predicciones_por_gap = {}

for gap_weeks in [3, 6, 9, 12]:
    resultados = []
    predicciones_todas = []

    for transformador in transformador_columnas_q:
        for estacion, meses in estaciones_meses.items():
            fechas = seleccionar_fechas_test(meses, gap_weeks)
            for fecha in fechas:
                try:
                    nombre_archivo = (
                        transformador.replace(" ", "_")
                        .replace(".", "")
                        .replace("(", "")
                        .replace(")", "")
                        .replace("/", "")
                    )
                    fecha_str = fecha.strftime("%Y-%m-%d_%H-%M")
                    ruta_grafico = os.path.join(
                        carpeta_graficos,
                        f"{nombre_archivo}_{fecha_str}_gap{gap_weeks}.png",
                    )

                    resultado, predicciones_test = ejecutar_modelo_prophet_parametros_estacion_manual(
                        df_transformadores,
                        columna=transformador,
                        fecha_inicio_test=fecha,
                        gap_weeks=gap_weeks,
                        mostrar_grafico=False,
                        ruta_guardado=ruta_grafico,
                    )

                    resultado["fecha_test"] = fecha
                    resultado["estacion"] = estacion
                    resultados.append(resultado)

                    predicciones_test["fecha_test"] = fecha
                    predicciones_test["estacion"] = estacion
                    predicciones_test["gap_semanas"] = gap_weeks
                    predicciones_todas.append(predicciones_test)

                except Exception as e:
                    print(f" Error en {transformador}, {fecha}, gap={gap_weeks}: {e}")

    resultados_por_gap[gap_weeks] = pd.DataFrame(resultados)
    predicciones_por_gap[gap_weeks] = (
        pd.concat(predicciones_todas, ignore_index=True) if predicciones_todas else pd.DataFrame()
    )

# === GUARDADO EN EXCEL ===
nombre_excel = os.path.join(output_dir, "resultados_prophet_estacional_por_gap_Q.xlsx")
with pd.ExcelWriter(nombre_excel, engine="openpyxl") as writer:
    for gap_weeks in resultados_por_gap:
        hoja_metricas = f"Metricas_gap{gap_weeks}"
        hoja_preds = f"Predicciones_gap{gap_weeks}"
        resultados_por_gap[gap_weeks].to_excel(writer, sheet_name=hoja_metricas, index=False)
        predicciones_por_gap[gap_weeks].to_excel(writer, sheet_name=hoja_preds, index=False)

print(" Resultados guardados correctamente con estacionalidades y gap (sin límite de 1 año).")
# Out:
# 13:06:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:07:41 - cmdstanpy - INFO - Chain [1] done processing
# 13:07:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:08 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:10:55 - cmdstanpy - INFO - Chain [1] done processing
# 13:10:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:13:20 - cmdstanpy - INFO - Chain [1] done processing
# 13:13:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:14:37 - cmdstanpy - INFO - Chain [1] done processing
# 13:14:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:16:30 - cmdstanpy - INFO - Chain [1] done processing
# 13:16:33 - cmdstanpy - INFO - Chain [1] start processing
# 13:17:50 - cmdstanpy - INFO - Chain [1] done processing
# 13:17:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:18:53 - cmdstanpy - INFO - Chain [1] done processing
# 13:18:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:19:21 - cmdstanpy - INFO - Chain [1] done processing
# 13:19:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:19:52 - cmdstanpy - INFO - Chain [1] done processing
# 13:19:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:20:23 - cmdstanpy - INFO - Chain [1] done processing
# 13:20:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:20:55 - cmdstanpy - INFO - Chain [1] done processing
# 13:20:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:21:29 - cmdstanpy - INFO - Chain [1] done processing
# 13:21:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:22:03 - cmdstanpy - INFO - Chain [1] done processing
# 13:22:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:22:17 - cmdstanpy - INFO - Chain [1] done processing
# 13:22:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:22:33 - cmdstanpy - INFO - Chain [1] done processing
# 13:22:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:18 - cmdstanpy - INFO - Chain [1] done processing
# 13:23:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:37 - cmdstanpy - INFO - Chain [1] done processing
# 13:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:04 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:40 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:50 - cmdstanpy - INFO - Chain [1] done processing
# 13:26:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:24 - cmdstanpy - INFO - Chain [1] done processing
# 13:28:26 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:13 - cmdstanpy - INFO - Chain [1] done processing
# 13:29:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:50 - cmdstanpy - INFO - Chain [1] done processing
# 13:29:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:10 - cmdstanpy - INFO - Chain [1] done processing
# 13:31:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:29 - cmdstanpy - INFO - Chain [1] done processing
# 13:32:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 13:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:06 - cmdstanpy - INFO - Chain [1] done processing
# 13:36:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:00 - cmdstanpy - INFO - Chain [1] done processing
# 13:38:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:16 - cmdstanpy - INFO - Chain [1] done processing
# 13:39:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:43 - cmdstanpy - INFO - Chain [1] done processing
# 13:40:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:41:36 - cmdstanpy - INFO - Chain [1] done processing
# 13:41:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:43:15 - cmdstanpy - INFO - Chain [1] done processing
# 13:43:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:45:28 - cmdstanpy - INFO - Chain [1] done processing
# 13:45:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:47:34 - cmdstanpy - INFO - Chain [1] done processing
# 13:47:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:48:59 - cmdstanpy - INFO - Chain [1] done processing
# 13:49:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:51:10 - cmdstanpy - INFO - Chain [1] done processing
# 13:51:14 - cmdstanpy - INFO - Chain [1] start processing
# 13:53:01 - cmdstanpy - INFO - Chain [1] done processing
# 13:53:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:55:46 - cmdstanpy - INFO - Chain [1] done processing
# 13:55:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:58:10 - cmdstanpy - INFO - Chain [1] done processing
# 13:58:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:59:56 - cmdstanpy - INFO - Chain [1] done processing
# 13:59:59 - cmdstanpy - INFO - Chain [1] start processing
# 14:01:45 - cmdstanpy - INFO - Chain [1] done processing
# 14:01:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:04:44 - cmdstanpy - INFO - Chain [1] done processing
# 14:04:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:06:58 - cmdstanpy - INFO - Chain [1] done processing
# 14:07:02 - cmdstanpy - INFO - Chain [1] start processing
# 14:09:16 - cmdstanpy - INFO - Chain [1] done processing
# 14:09:19 - cmdstanpy - INFO - Chain [1] start processing
# 14:11:16 - cmdstanpy - INFO - Chain [1] done processing
# 14:11:19 - cmdstanpy - INFO - Chain [1] start processing
# 14:12:34 - cmdstanpy - INFO - Chain [1] done processing
# 14:12:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:13:26 - cmdstanpy - INFO - Chain [1] done processing
# 14:13:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:14:05 - cmdstanpy - INFO - Chain [1] done processing
# 14:14:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:14:33 - cmdstanpy - INFO - Chain [1] done processing
# 14:14:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:15:07 - cmdstanpy - INFO - Chain [1] done processing
# 14:15:10 - cmdstanpy - INFO - Chain [1] start processing
# 14:15:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:15:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:27 - cmdstanpy - INFO - Chain [1] done processing
# 14:16:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:17:19 - cmdstanpy - INFO - Chain [1] done processing
# 14:17:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:17:39 - cmdstanpy - INFO - Chain [1] done processing
# 14:17:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:17:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:17:56 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:15 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:54 - cmdstanpy - INFO - Chain [1] start processing
# 14:19:31 - cmdstanpy - INFO - Chain [1] done processing
# 14:19:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:20:25 - cmdstanpy - INFO - Chain [1] done processing
# 14:20:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:22:14 - cmdstanpy - INFO - Chain [1] done processing
# 14:22:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:23:14 - cmdstanpy - INFO - Chain [1] done processing
# 14:23:17 - cmdstanpy - INFO - Chain [1] start processing
# 14:23:55 - cmdstanpy - INFO - Chain [1] done processing
# 14:23:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:24:41 - cmdstanpy - INFO - Chain [1] done processing
# 14:24:44 - cmdstanpy - INFO - Chain [1] start processing
# 14:26:14 - cmdstanpy - INFO - Chain [1] done processing
# 14:26:17 - cmdstanpy - INFO - Chain [1] start processing
# 14:27:10 - cmdstanpy - INFO - Chain [1] done processing
# 14:27:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:29:08 - cmdstanpy - INFO - Chain [1] done processing
# 14:29:12 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:11 - cmdstanpy - INFO - Chain [1] done processing
# 14:31:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:26 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:37 - cmdstanpy - INFO - Chain [1] done processing
# 14:34:40 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:30 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:26 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 14:38:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:08 - cmdstanpy - INFO - Chain [1] done processing
# 14:41:12 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:42:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:45 - cmdstanpy - INFO - Chain [1] done processing
# 14:43:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:45:35 - cmdstanpy - INFO - Chain [1] done processing
# 14:45:38 - cmdstanpy - INFO - Chain [1] start processing
# 14:47:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:47:44 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 14:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:55 - cmdstanpy - INFO - Chain [1] done processing
# 14:52:58 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:54:25 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:08 - cmdstanpy - INFO - Chain [1] done processing
# 14:56:11 - cmdstanpy - INFO - Chain [1] start processing
# 14:58:11 - cmdstanpy - INFO - Chain [1] done processing
# 14:58:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:59:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:59:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:01:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:01:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:20 - cmdstanpy - INFO - Chain [1] done processing
# 15:02:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:03:01 - cmdstanpy - INFO - Chain [1] done processing
# 15:03:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:03:25 - cmdstanpy - INFO - Chain [1] done processing
# 15:03:28 - cmdstanpy - INFO - Chain [1] start processing
# 15:03:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:03:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:05:19 - cmdstanpy - INFO - Chain [1] done processing
# 15:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:00 - cmdstanpy - INFO - Chain [1] done processing
# 15:06:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:13 - cmdstanpy - INFO - Chain [1] done processing
# 15:06:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:23 - cmdstanpy - INFO - Chain [1] done processing
# 15:06:26 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:06:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:07:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:07:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:33 - cmdstanpy - INFO - Chain [1] done processing
# 15:15:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:14 - cmdstanpy - INFO - Chain [1] done processing
# 15:23:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:24:17 - cmdstanpy - INFO - Chain [1] done processing
# 15:24:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:25:13 - cmdstanpy - INFO - Chain [1] done processing
# 15:25:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:33:10 - cmdstanpy - INFO - Chain [1] done processing
# 15:33:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:33:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:33:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:34:31 - cmdstanpy - INFO - Chain [1] done processing
# 15:34:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:36:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:47:03 - cmdstanpy - INFO - Chain [1] done processing
# 15:47:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:48:16 - cmdstanpy - INFO - Chain [1] done processing
# 15:48:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:52:06 - cmdstanpy - INFO - Chain [1] done processing
# 15:52:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:54:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:54:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:55:59 - cmdstanpy - INFO - Chain [1] done processing
# 15:56:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:56:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:56:48 - cmdstanpy - INFO - Chain [1] start processing
# 16:00:03 - cmdstanpy - INFO - Chain [1] done processing
# 16:00:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:03:14 - cmdstanpy - INFO - Chain [1] done processing
# 16:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 16:04:49 - cmdstanpy - INFO - Chain [1] done processing
# 16:04:54 - cmdstanpy - INFO - Chain [1] start processing
# 16:07:46 - cmdstanpy - INFO - Chain [1] done processing
# 16:07:49 - cmdstanpy - INFO - Chain [1] start processing
# 16:09:26 - cmdstanpy - INFO - Chain [1] done processing
# 16:09:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:11:15 - cmdstanpy - INFO - Chain [1] done processing
# 16:11:18 - cmdstanpy - INFO - Chain [1] start processing
# 16:13:04 - cmdstanpy - INFO - Chain [1] done processing
# 16:13:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:14:47 - cmdstanpy - INFO - Chain [1] done processing
# 16:14:50 - cmdstanpy - INFO - Chain [1] start processing
# 16:16:14 - cmdstanpy - INFO - Chain [1] done processing
# 16:16:17 - cmdstanpy - INFO - Chain [1] start processing
# 16:17:50 - cmdstanpy - INFO - Chain [1] done processing
# 16:17:53 - cmdstanpy - INFO - Chain [1] start processing
# 16:19:54 - cmdstanpy - INFO - Chain [1] done processing
# 16:19:57 - cmdstanpy - INFO - Chain [1] start processing
# 16:21:23 - cmdstanpy - INFO - Chain [1] done processing
# 16:21:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:23:11 - cmdstanpy - INFO - Chain [1] done processing
# 16:23:14 - cmdstanpy - INFO - Chain [1] start processing
# 16:24:37 - cmdstanpy - INFO - Chain [1] done processing
# 16:24:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:25:19 - cmdstanpy - INFO - Chain [1] done processing
# 16:25:21 - cmdstanpy - INFO - Chain [1] start processing
# 16:25:46 - cmdstanpy - INFO - Chain [1] done processing
# 16:25:49 - cmdstanpy - INFO - Chain [1] start processing
# 16:26:01 - cmdstanpy - INFO - Chain [1] done processing
# 16:26:04 - cmdstanpy - INFO - Chain [1] start processing
# 16:26:19 - cmdstanpy - INFO - Chain [1] done processing
# 16:26:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:26:49 - cmdstanpy - INFO - Chain [1] done processing
# 16:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 16:27:13 - cmdstanpy - INFO - Chain [1] done processing
# 16:27:17 - cmdstanpy - INFO - Chain [1] start processing
# 16:27:55 - cmdstanpy - INFO - Chain [1] done processing
# 16:27:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:28:30 - cmdstanpy - INFO - Chain [1] done processing
# 16:28:33 - cmdstanpy - INFO - Chain [1] start processing
# 16:28:41 - cmdstanpy - INFO - Chain [1] done processing
# 16:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 16:28:52 - cmdstanpy - INFO - Chain [1] done processing
# 16:28:55 - cmdstanpy - INFO - Chain [1] start processing
# 16:29:35 - cmdstanpy - INFO - Chain [1] done processing
# 16:29:38 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:04 - cmdstanpy - INFO - Chain [1] done processing
# 16:30:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:46 - cmdstanpy - INFO - Chain [1] done processing
# 16:30:49 - cmdstanpy - INFO - Chain [1] start processing
# 16:31:41 - cmdstanpy - INFO - Chain [1] done processing
# 16:31:44 - cmdstanpy - INFO - Chain [1] start processing
# 16:32:36 - cmdstanpy - INFO - Chain [1] done processing
# 16:32:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:33:43 - cmdstanpy - INFO - Chain [1] done processing
# 16:33:46 - cmdstanpy - INFO - Chain [1] start processing
# 16:34:21 - cmdstanpy - INFO - Chain [1] done processing
# 16:34:23 - cmdstanpy - INFO - Chain [1] start processing
# 16:34:44 - cmdstanpy - INFO - Chain [1] done processing
# 16:34:47 - cmdstanpy - INFO - Chain [1] start processing
# 16:35:38 - cmdstanpy - INFO - Chain [1] done processing
# 16:35:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:36:15 - cmdstanpy - INFO - Chain [1] done processing
# 16:36:19 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:21 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:24 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:29 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:54 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:57 - cmdstanpy - INFO - Chain [1] start processing
# 16:41:09 - cmdstanpy - INFO - Chain [1] done processing
# 16:41:11 - cmdstanpy - INFO - Chain [1] start processing
# 16:41:38 - cmdstanpy - INFO - Chain [1] done processing
# 16:41:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:42:01 - cmdstanpy - INFO - Chain [1] done processing
# 16:42:04 - cmdstanpy - INFO - Chain [1] start processing
# 16:44:03 - cmdstanpy - INFO - Chain [1] done processing
# 16:44:05 - cmdstanpy - INFO - Chain [1] start processing
# 16:46:01 - cmdstanpy - INFO - Chain [1] done processing
# 16:46:04 - cmdstanpy - INFO - Chain [1] start processing
# 16:48:04 - cmdstanpy - INFO - Chain [1] done processing
# 16:48:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:49:36 - cmdstanpy - INFO - Chain [1] done processing
# 16:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 16:51:25 - cmdstanpy - INFO - Chain [1] done processing
# 16:51:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:44 - cmdstanpy - INFO - Chain [1] done processing
# 16:53:46 - cmdstanpy - INFO - Chain [1] start processing
# 16:55:26 - cmdstanpy - INFO - Chain [1] done processing
# 16:55:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:56:46 - cmdstanpy - INFO - Chain [1] done processing
#  Resultados guardados correctamente con estacionalidades y gap (sin límite de 1 año).
